# %% [markdown]
# # Import

# %%
import csv
import os
import pickle
import sys
from itertools import product, chain
from typing import Dict, List

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor, as_completed

# %% [markdown]
# ## Add configuration file

# %%
sys.path.append("/home/jovyan/core/config/")
sys.path.append("/home/jovyan/core/util/")
sys.path.append("../PlotFunction/lineplot/")
sys.path.append("../PlotFunction/config/")

# %%
from ALL import config
import MultilayerDict as md
from line_plot_1 import line_plot_1
from line_plot_error_1 import line_plot_error_1
from line_plot_error_1_layout import layout
from util import *

# %% [markdown]
# ## Set condition

# %%
tqdm.pandas()
pd.set_option("display.max_columns", 100)
pd.set_option("display.max_rows", 50)

# %%
s3 = S3Manager()

# %%
sampling_nums = [1, 2, 4, 8, 16, 32, 64, 128]

# %%
data_types = [f"20NewsSampled{sampling_num}" for sampling_num in sampling_nums]
vectorize_type = "sentenceBERT"
transformer_models = [
    "sentence-transformers/all-MiniLM-L6-v2",
    "sentence-transformers/all-mpnet-base-v2",
    "sentence-transformers/all-distilroberta-v1",
]

# %%
transformer_model = transformer_models[0]
data_type = data_types[0]

# %%
vector_dims = config["vectorize"][vectorize_type][transformer_model]["dims"]
normalizations = config["vectorize"][vectorize_type][transformer_model]["normalization"]
vector_model_nums = config["vectorize"][vectorize_type][transformer_model]["max_model_num"]

model_nums = config["clustering"]["gmm"]["max_model_num"]
covariance_types = config["clustering"]["gmm"]["covariance_types"]
topic_nums = config["data"][data_type_classifier(data_type)]["class_num"]
depression_type = "umap"

# %%
stats_vals = ["aic", "bic", "mi", "logl"]

# %%
names_keys = {"stats": ["aic", "bic", "mi", "logl"]}

# %% [markdown]
# # Read data

# %%
if vectorize_type == "doc2vec":
    stats_base_paths = [
        f"Postprocessing/{data_type}/{vectorize_type}/GMM/stat"
        for data_type in data_types
    ]
elif vectorize_type == "sentenceBERT":
    stats_base_paths = [
        [
            f"Postprocessing/{data_type}/{vectorize_type}/{transformer_model}/GMM/stat"
            for data_type in data_types
        ]
        for transformer_model in transformer_models
    ]
else:
    raise NotImplementedError

# %%
stats_base_paths = list(chain.from_iterable(stats_base_paths))

# %%
with ThreadPoolExecutor(max_workers=15) as executor:
    f = []
    for stats_base_path in stats_base_paths:
        f.append(executor.submit(s3.download, stats_base_path))
    for f in tqdm(as_completed(f), total=len(f)):
        pass  # 処理終了を待つ
# Out:
# 100%|██████████| 24/24 [00:56<00:00,  2.35s/it]

# %%
multi_ds = []
keys = []
for (
    vector_dim,
    normalization,
    vector_model_num,
    covariance_type,
    topic_num,
    model_num,
) in tqdm(
    list(product(
        vector_dims,
        normalizations,
        range(vector_model_nums),
        covariance_types,
        topic_nums,
        range(model_nums),
    ))
):
    stats_path = f"{root_path_temporary}{stats_base_path}/{vector_dim}/{normalization}/{vector_model_num}/{covariance_type}/{topic_num}/{model_num}.csv"
    multi_d = md.read_csv(stats_path, names_keys=names_keys)
    multi_ds.append(multi_d)
    keys.append(
        [
            vector_dim,
            normalization,
            vector_model_num,
            covariance_type,
            topic_num,
            model_num,
        ]
    )
# Out:
#   0%|          | 0/840 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[36], line 21
#       3 for (
#       4     vector_dim,
#       5     normalization,
#    (...)
#      18     ))
#      19 ):
#      20     stats_path = f"{root_path_temporary}{stats_base_path}/{vector_dim}/{normalization}/{vector_model_num}/{covariance_type}/{topic_num}/{model_num}.csv"
# ---> 21     multi_d = md.read_csv(stats_path, names_keys=names_keys)
#      22     multi_ds.append(multi_d)
#      23     keys.append(
#      24         [
#      25             vector_dim,
#    (...)
#      31         ]
#      32     )
#
# File ~/core/util/MultilayerDict.py:366, in read_csv(file_path, names_keys, encoding, newline, delimiter, quotechar)
#     364     return MultilayerDict(names_keys, _dict)
#     365 elif len(names_keys) == 1:
# --> 366     with open(file_path, mode="r", encoding=encoding, newline=newline) as _f:
#     367         _dict = list(
#     368             csv.DictReader(
#     369                 _f,
#    (...)
#     372             )
#     373         )[0]
#     374     return MultilayerDict(names_keys, _dict)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/jovyan/temporary/Postprocessing/20NewsSampled128/sentenceBERT/sentence-transformers/all-distilroberta-v1/GMM/stat/2/normalized/0/spherical/20/0.csv'

# %%
multi_d = md.MultilayerDict(
    names_keys={
        "vector_dim": vector_dims,
        "normalization": normalizations,
        "vector_model_num": range(vector_model_nums),
        "covariance_type": covariance_types,
        "topic_num": topic_nums,
        "model_num": range(model_nums),
    }
)

# %%
multi_d = multi_d.extend(keys, multi_ds)

# %%
# lda_mi = pd.read_csv(f"../../Postprocessing/data/{data_type}/LDA/mi.csv", index_col=0)

# %%
# describe_lda_mi, _ = get_describe(lda_mi, axis=0)

# %% [markdown]
# # Data shaping

# %%
multi_d = md.swap_keys(
    multi_d,
    [
        "vector_dim",
        "normalization",
        "vector_model_num",
        "covariance_type",
        "topic_num",
        "stats",
        "model_num",
    ],
)

# %%
def get_keys(names: List, names_keys:Dict)->List:
    return [names_keys[name] for name in names]

# %%
keys = get_keys(
    [
        "vector_dim",
        "normalization",
        "vector_model_num",
        "covariance_type",
        "topic_num",
    ],
    multi_d.names_keys,
)

# %%
for key in product(*keys):
    df = pd.DataFrame(multi_d.loc(key), dtype="float64")
    multi_d.update(key, df)

# %%
multi_d = multi_d.drop_names(names=["stats", "model_num"])

# %%
for key in product(*keys):
    describe, desciribe_key = get_describe(multi_d.loc(key), axis=0, return_dict=True)
    multi_d.update(key, describe)

# %%
multi_d = multi_d.add_names({"agg_type":['mean', 'median', 'std', 'var', '75', '25'], "stats": stats_vals})

# %%
multi_d = md.swap_keys(
    multi_d,
    [
        "normalization",
        "vector_model_num",
        "topic_num",
        "stats",
        "agg_type",
        "vector_dim",
        "covariance_type",
    ],
)

# %%
keys = get_keys(
    [
        "normalization",
        "vector_model_num",
        "topic_num",
        "stats",
    ],
    multi_d.names_keys,
)

# %%
for key in product(*keys):
    df = pd.DataFrame(multi_d.loc(key)["mean"])
    multi_d.update(key, df)

# %%
multi_d = multi_d.drop_names(["agg_type", "vector_dim", "covariance_type"])

# %%
keys = get_keys(
    [
        "normalization",
        "vector_model_num",
        "topic_num",
        "stats",
    ],
    multi_d.names_keys,
)

# %% [markdown]
# # Plot

# %%
xlabel="埋め込み次元"
ylabel="mi"
yticks=np.arange(0, 1.1, 0.1)
title=f"{data_type}    ({vectorize_type})"

# %%
for key in product(*keys):
    fig = plt.figure(**layout["figure"])
    ax = fig.add_subplot(111)
    fig_path = f"/home/jovyan/temporary/Visualize/{data_type}/{vectorize_type}/{transformer_model}/temp.pdf"
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)

    ax.set_xscale("log")
    
    for covariance_type in covariance_types:
        ax.plot(multi_d.loc(key).loc[covariance_type, :], label=covariance_type)
        
    ax.set_title(title, **layout["title"])

    ax.set_xlabel(xlabel, **layout["label"])
    ax.set_ylabel(key[-1], **layout["label"])
    if key[-1] == "mi":
        ax.set_yticks(ticks=yticks, **layout["ticks"])
    ax.legend(**layout["legend"])

    fig.savefig(make_filepath(fig_path))
